# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def potential(xx,yy):
    for i in range(0,25):
        for j in range(0,25):
            pass


x = np.linspace(-25,25,25)
y = np.linspace(-25,25,25)
xx,yy = np.meshgrid(x,y)

print(xx.shape)

plt.figure(figsize=(10, 6))
plt.plot(xx,yy, marker='.', linestyle='none', color='k')
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.title("Meshgrid")
plt.show()
# Out:
# (25, 25)
